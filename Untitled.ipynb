# %%
import csv

class Employee:
    def __init__(self, name, age, salary):
        self.__name = name 
        self.__age = age
        self.__salary = salary

    #name
    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    #age 
    def get_age(self):
        return self.__age

    def set_age(self, age):
        if self.__age >= 0:
            self.__age == age
        else:
            print('enter appropriate age / age cannot be negative')

    #salary
    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if self.__salary >= 0:
            self.__salary = salary
        else:
            print('salary cannot be negative')

class Manager(Employee):
    def __init__(self, name, age, salary, department):
        super().__init(name, age, salary)
        self.__department = department
        
    #department
    def get_department(self):
        return self.__department

    def set_department(self, department):
        self.__department = department

class Worker(Employee):
    def __init__(self, name, age, salary, hours_worked):
        super().__init(name, age, salary)
        self.__hours_worked = hours_worked

    #hours_worked
    def get_hours_worked(self):
        return self.__hours_worked
        
    def set_hours_woked(self, hours_worked):
        if self.__hours_worked >= 0:
            self.__hours_worked = hours_worked

        else:
            print('hours cannot be negative / enter appropriate number')

def save(filename, employees):
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(['Name', 'Age', 'Salary', 'Department', 'Hours worked'])
        for employee in employees:
            if isinstance(employee, Manager):
                writer.writerows([employee.get_name, employee.get_age, employee.get_salary, employee.get_department, 'N/A'])
            elif isinstance(employee, Worker):
                writer.writerows([employee.get_name, employee.get_age, employee.get_salary, 'N/A', employee.get_hours_worked])

def load(filename):
    employees = []

    with open(filename, mode = 'r') as file:
        reader = csv.reader(file)
        next(reader) #skips header
        for row in reader:
            name, age, salary, department, hours_worked = row
            age = int(age)
            salary = float(salary)
            if department:
                employees.append(Manager(name, age, salary, department))
            else:
                employees.append(Worker(name, age, salary, hours_worked))
        
        return employees
    
def add(employees, type):
    name = input('Enter the Name: ')
    age = int(input('Enter the Age: '))
    salary = float(input('Enter the Salary: '))

    if type == 'Manager':
        department = input('enter the department')
        employees.append(Manager(name, age, salary, department))

    elif type == 'Worker':
        hours_worked = float(input('Enter the number of hours worked: '))
        employees.append(Worker(name, age, salary, hours_worked))

    else:
        input('enter the type correctly either Manager/Worker !')


def update(employees):
    name = input('enter the name to update: ')
    for emp in employees:
        if emp.get_name == name:
            emp.get_name = input('enter the new Name: ')
            emp.get_age = int(input('enter the new Age: '))
            emp.get_salary = float(input('enter the new salary: '))
            if isinstance(employees, Manager):
                emp.get_department = input('Enter the new department: ')
            elif isinstance(employees, Worker):
                emp.get_hours_worked = float(input('Enter the updated number of hours worked: '))
            print('UPDATED SUCCESSFULLY !')
            return
        else:
            print(f'no employee found with such {name} name !')

def delete(employees):
    name = input('Enter the name of the employee to erase data: ')
    for emp in employees:
        if emp.get_name == name:
            employees.remove(emp)
            print('Employee deleted successfully !')
            return
        else:
            print('ERROR NOT FOUND')

def display(employees):
    for emp in employees:
        print(f'Name: {emp.get_name}, Age: {emp.get_age}, Salary: {emp.get_salary}')

        if isinstance(employees, Manager):
            print(f'department: {emp.get_department}')
        else:
            print(f'hours_worked : {emp.get_hours_worked}')
        print('-'*30)



def main():
    employees = []
    filename = 'assignment10.csv'

    while True:
        print("\n1. Add Manager")
        print("2. Add Worker")
        print("3. Display Employees")
        print("4. Update Employee")
        print("5. Delete Employee")
        print("6. Save to File")
        print("7. Load from File")
        print("8. Exit")

        choice = input('enter your choice: ')
        if choice == '1':
            add(employees, "Manager")
        elif choice == '2':
            add(employees, "Worker")
        elif choice == '3':
            display(employees)
        elif choice == '4':
            update(employees)
        elif choice == '5':
            delete(employees)
        elif choice == '6':
            save(filename, employees)
            print("Employees saved to file.")
        elif choice == '7':
            employees = load(filename)
            print("Employees loaded from file.")
        elif choice == '8':
            break
        else:
            print("Invalid choice! Please try again.")

main()
# Out:
# 1. Add Manager
# 2. Add Worker
# 3. Display Employees
# 4. Update Employee
# 5. Delete Employee
# 6. Save to File
# 7. Load from File
# 8. Exit
# enter your choice:  1
# Enter the Name:  hzy
# Enter the Age:  23
# Enter the Salary:  100000
# enter the department se
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 182
#     179         else:
#     180             print("Invalid choice! Please try again.")
# --> 182 main()
#
# Cell In[1], line 162, in main()
#     160 choice = input('enter your choice: ')
#     161 if choice == '1':
# --> 162     add(employees, "Manager")
#     163 elif choice == '2':
#     164     add(employees, "Worker")
#
# Cell In[1], line 98, in add(employees, type)
#      96 if type == 'Manager':
#      97     department = input('enter the department')
# ---> 98     employees.append(Manager(name, age, salary, department))
#     100 elif type == 'Worker':
#     101     hours_worked = float(input('Enter the number of hours worked: '))
#
# Cell In[1], line 38, in Manager.__init__(self, name, age, salary, department)
#      37 def __init__(self, name, age, salary, department):
# ---> 38     super().__init(name, age, salary)
#      39     self.__department = department
#
# AttributeError: 'super' object has no attribute '_Manager__init'
